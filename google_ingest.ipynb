# %% [markdown]
# ## ingest

# %%
dataset_id = "google_staging"

# %%
# !bq --location=US mk --dataset {dataset_id}
# Out:
# Dataset 'spry-cosine-266801:google_staging' successfully created.

# %%
# !bq --location=US load --autodetect --skip_leading_rows=1 \
--source_format=CSV {dataset_id}.mobility_report \
'gs://covid-19-csv-jy/Global_Mobility_Report.csv'
# Out:
# Waiting on bqjob_r6e4ecb2160004974_00000171e69965b2_1 ... (4s) Current status: DONE

# %%
# %%bigquery
# select count(*) from google_staging.mobility_report
# Out:
#       f0_
# 0  284489

# %%
# %%bigquery
# select * from google_staging.mobility_report
# limit 12
# Out:
#    country_region_code        country_region sub_region_1 sub_region_2  \
# 0                   AE  United Arab Emirates         None         None
# 1                   AE  United Arab Emirates         None         None
# 2                   AE  United Arab Emirates         None         None
# 3                   AE  United Arab Emirates         None         None
# 4                   AE  United Arab Emirates         None         None
# 5                   AE  United Arab Emirates         None         None
# 6                   AE  United Arab Emirates         None         None
# 7                   AE  United Arab Emirates         None         None
# 8                   AE  United Arab Emirates         None         None
# 9                   AE  United Arab Emirates         None         None
# 10                  AE  United Arab Emirates         None         None
# 11                  AE  United Arab Emirates         None         None
#
# ...
